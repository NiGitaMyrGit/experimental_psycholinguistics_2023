# %%
# %pip install lxml
import pandas as pd
# Out:
# Collecting lxml
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/3c/d2/11533f0bc47ff4d828a20cfb702f3453fe714bd5b475fcdc8cec6e6b7dcf/lxml-4.9.3-cp310-cp310-manylinux_2_28_x86_64.whl.metadata
#   Downloading lxml-4.9.3-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Downloading lxml-4.9.3-cp310-cp310-manylinux_2_28_x86_64.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 33.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: lxml
# Successfully installed lxml-4.9.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# scrape table data from websites

rawdata = pd.read_html("https://en.wikipedia.org/wiki/List_of_Sesame_Street_Muppets")
df = rawdata[1]
df
# Out:
#                   Character  \
# 0              Abby Cadabby
# 1       Alice Snuffleupagus
# 2           Alistair Cookie
# 3       The Amazing Mumford
# 4          Anything Muppets
# ..                      ...
# 114           Telly Monster
# 115         The Twiddlebugs
# 116  The Two-Headed Monster
# 117                     Wes
# 118                     Zoe
#
#                                 Actor/Muppet performer  \
# 0                           Leslie Carrara-Rudolph[13]
# 1                                      Judy Sladky[15]
# 2                                         Frank Oz[17]
# 3                   Jerry Nelson,[20] John Kennedy[21]
# 4                                          Various[22]
# ..                                                 ...
# 114  Bob Payne (1979), Brian Muehl (1979–1984),[126...
# 115  Jim Henson, Frank Oz, Jerry Nelson, Richard Hu...
# 116  Left Head: Jerry Nelson[40] Right Head: Richar...
# 117  Leslie Carrara-Rudolph, Kevin Clash, Carmen Os...
# 118  Fran Brill (1993–2015),[141] Jennifer Barnhart...
#
#                                            Description  \
# 0    A 4-year-old fairy-in-training with tiny wings...
# 1    Baby sister of Aloysius Snuffleupagus ("Snuffy...
# 2    Played by Cookie Monster, he is a parody of Br...
# 3    A "W.C. Fields-esque" magician whose magic tri...
# 4    Writer Christopher Finch called Anything Muppe...
# ..                                                 ...
# 114  According to Sesame Workshop, "Telly Monster i...
# 115  A family of fuzzy insects (Thomas, Tessie and ...
# 116  A purple monster with two heads, who generally...
# 117                                                NaN
# 118  Introduced to increase the number of strong fe...
#
#                                             Unnamed: 3
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Writer Christopher Finch called Anything Muppe...
# ..                                                 ...
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
#
# [119 rows x 4 columns]

# %%
# take a column from a dataframe and assign it to a list variable

a = list(df.Character)
len(a)
# Out:
# 119

# %%
a[0:4]
# Out:
# ['Abby Cadabby',
#  'Alice Snuffleupagus',
#  'Alistair Cookie',
#  'The Amazing Mumford']

# %%
a[-3:]
# Out:
# ['The Two-Headed Monster', 'Wes', 'Zoe']

# %%
a[-3:]
# Out:
# ['The Two-Headed Monster', 'Wes', 'Zoe']

# %%
a[7:10]
# Out:
# ['Arlene Frantic', 'Baby Bear', 'Barkley']

# %%
# select the first 20 items from a list
b = a[0:20]
b
# Out:
# ['Abby Cadabby',
#  'Alice Snuffleupagus',
#  'Alistair Cookie',
#  'The Amazing Mumford',
#  'Anything Muppets',
#  'AM Monsters',
#  'Aristotle',
#  'Arlene Frantic',
#  'Baby Bear',
#  'Barkley',
#  'Beautiful Day Monster',
#  'Bennett Snerf',
#  'Benny Rabbit',
#  'Bert',
#  'Betty Lou',
#  'Biff',
#  'Big Bird',
#  'Bip Bippadotta',
#  'Bruno the Trashman',
#  'Buster']

# %%
# remove the last item in a list
b.pop()
# Out:
# 'Buster'

# %%
b
# Out:
# ['Abby Cadabby',
#  'Alice Snuffleupagus',
#  'Alistair Cookie',
#  'The Amazing Mumford',
#  'Anything Muppets',
#  'AM Monsters',
#  'Aristotle',
#  'Arlene Frantic',
#  'Baby Bear',
#  'Barkley',
#  'Beautiful Day Monster',
#  'Bennett Snerf',
#  'Benny Rabbit',
#  'Bert',
#  'Betty Lou',
#  'Biff',
#  'Big Bird',
#  'Bip Bippadotta',
#  'Bruno the Trashman']

# %%
b.append('Kermit')

# %%
b
# Out:
# ['Abby Cadabby',
#  'Alice Snuffleupagus',
#  'Alistair Cookie',
#  'The Amazing Mumford',
#  'Anything Muppets',
#  'AM Monsters',
#  'Aristotle',
#  'Arlene Frantic',
#  'Baby Bear',
#  'Barkley',
#  'Beautiful Day Monster',
#  'Bennett Snerf',
#  'Benny Rabbit',
#  'Bert',
#  'Betty Lou',
#  'Biff',
#  'Big Bird',
#  'Bip Bippadotta',
#  'Bruno the Trashman',
#  'Kermit']

# %%
# insert an item into a list at a particular position
b.insert(5, 'Kermit')
b
# Out:
# ['Abby Cadabby',
#  'Alice Snuffleupagus',
#  'Alistair Cookie',
#  'The Amazing Mumford',
#  'Anything Muppets',
#  'Kermit',
#  'AM Monsters',
#  'Aristotle',
#  'Arlene Frantic',
#  'Baby Bear',
#  'Barkley',
#  'Beautiful Day Monster',
#  'Bennett Snerf',
#  'Benny Rabbit',
#  'Bert',
#  'Betty Lou',
#  'Biff',
#  'Big Bird',
#  'Bip Bippadotta',
#  'Bruno the Trashman',
#  'Kermit']

# %%
b[1]='Fozzy Bear'
b
# Out:
# ['Abby Cadabby',
#  'Fozzy Bear',
#  'Alistair Cookie',
#  'The Amazing Mumford',
#  'Anything Muppets',
#  'Kermit',
#  'AM Monsters',
#  'Aristotle',
#  'Arlene Frantic',
#  'Baby Bear',
#  'Barkley',
#  'Beautiful Day Monster',
#  'Bennett Snerf',
#  'Benny Rabbit',
#  'Bert',
#  'Betty Lou',
#  'Biff',
#  'Big Bird',
#  'Bip Bippadotta',
#  'Bruno the Trashman',
#  'Kermit']

# %%
# use list comprehensions to manipulate items in a list in a vectorized fashion 
c = [x + ' is a cute monster' for x in b]
c
# Out:
# ['Abby Cadabby is a cute monster',
#  'Fozzy Bear is a cute monster',
#  'Alistair Cookie is a cute monster',
#  'The Amazing Mumford is a cute monster',
#  'Anything Muppets is a cute monster',
#  'Kermit is a cute monster',
#  'AM Monsters is a cute monster',
#  'Aristotle is a cute monster',
#  'Arlene Frantic is a cute monster',
#  'Baby Bear is a cute monster',
#  'Barkley is a cute monster',
#  'Beautiful Day Monster is a cute monster',
#  'Bennett Snerf is a cute monster',
#  'Benny Rabbit is a cute monster',
#  'Bert is a cute monster',
#  'Betty Lou is a cute monster',
#  'Biff is a cute monster',
#  'Big Bird is a cute monster',
#  'Bip Bippadotta is a cute monster',
#  'Bruno the Trashman is a cute monster',
#  'Kermit is a cute monster']

# %%
b = a[0:20]
b
# Out:
# ['Abby Cadabby',
#  'Alice Snuffleupagus',
#  'Alistair Cookie',
#  'The Amazing Mumford',
#  'Anything Muppets',
#  'AM Monsters',
#  'Aristotle',
#  'Arlene Frantic',
#  'Baby Bear',
#  'Barkley',
#  'Beautiful Day Monster',
#  'Bennett Snerf',
#  'Benny Rabbit',
#  'Bert',
#  'Betty Lou',
#  'Biff',
#  'Big Bird',
#  'Bip Bippadotta',
#  'Bruno the Trashman',
#  'Buster']

# %%
# use list comprehensions to compare two lists, and select items from list 1 that match items in list 2

favs = ['Barkley',  'Betty Lou', 'Bert', 'Kermit']
c = [x for x in b if x in favs]
c
# Out:
# ['Barkley', 'Bert', 'Betty Lou']

# %%
# use list comprehensions to compare two lists, and select items from list 1 that are not in list 2
b = a[0:20]
favs = ['Barkley',  'Betty Lou', 'Bert']
c = [x for x in b if x not in favs]
c

# this gives us all the monters in the list that are NOT my favorites

# Not really. I love all monsters.
# Out:
# ['Abby Cadabby',
#  'Alice Snuffleupagus',
#  'Alistair Cookie',
#  'The Amazing Mumford',
#  'Anything Muppets',
#  'AM Monsters',
#  'Aristotle',
#  'Arlene Frantic',
#  'Baby Bear',
#  'Beautiful Day Monster',
#  'Bennett Snerf',
#  'Benny Rabbit',
#  'Biff',
#  'Big Bird',
#  'Bip Bippadotta',
#  'Bruno the Trashman',
#  'Buster']

# %%
d = [1,2,3,4,5]
d = [x + 10 for x in d]
d
# Out:
# [11, 12, 13, 14, 15]

# %%
d = [x / 2 for x in d]
d
# Out:
# [5.5, 6.0, 6.5, 7.0, 7.5]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ethanweed/ExPsyLing/master/Data/StudentSleep.csv")
df
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6
# 0         10          8          4         12         10          6
# 1          7          8          3         14          5          6
# 2          7          7          5         11          8          8
# 3          8          9          6         10          9          5
# 4          2          6          6         12          5          6
# 5          5          7          5         14          6          7
# 6          6          7          6         12          9          7

# %%
df.shape
# Out:
# (7, 6)

# %%
df1 = df.iloc[0:4]
df1
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6
# 0         10          8          4         12         10          6
# 1          7          8          3         14          5          6
# 2          7          7          5         11          8          8
# 3          8          9          6         10          9          5

# %%
df.shape[0]
# Out:
# 7

# %%
df2 = df.iloc[4:df.shape[0]]
df2
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6
# 4          2          6          6         12          5          6
# 5          5          7          5         14          6          7
# 6          6          7          6         12          9          7

# %%
df3 = pd.concat([df2, df1])
df3
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6
# 4          2          6          6         12          5          6
# 5          5          7          5         14          6          7
# 6          6          7          6         12          9          7
# 0         10          8          4         12         10          6
# 1          7          8          3         14          5          6
# 2          7          7          5         11          8          8
# 3          8          9          6         10          9          5

# %%
df3.iloc[1]
# Out:
# Student 1     5
# Student 2     7
# Student 3     5
# Student 4    14
# Student 5     6
# Student 6     7
# Name: 5, dtype: int64

# %%
df3 = pd.concat([df1, df2])
df3
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6
# 0         10          8          4         12         10          6
# 1          7          8          3         14          5          6
# 2          7          7          5         11          8          8
# 3          8          9          6         10          9          5
# 4          2          6          6         12          5          6
# 5          5          7          5         14          6          7
# 6          6          7          6         12          9          7

# %%
df3['average'] = df3.mean(axis = 1)
df3
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6   average
# 0         10          8          4         12         10          6  8.333333
# 1          7          8          3         14          5          6  7.166667
# 2          7          7          5         11          8          8  7.666667
# 3          8          9          6         10          9          5  7.833333
# 4          2          6          6         12          5          6  6.166667
# 5          5          7          5         14          6          7  7.333333
# 6          6          7          6         12          9          7  7.833333

# %%
m = df3.pop('average')

# %%
list(m)
# Out:
# [8.333333333333334,
#  7.166666666666667,
#  7.666666666666667,
#  7.833333333333333,
#  6.166666666666667,
#  7.333333333333333,
#  7.833333333333333]

# %%
df3
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6
# 0         10          8          4         12         10          6
# 1          7          8          3         14          5          6
# 2          7          7          5         11          8          8
# 3          8          9          6         10          9          5
# 4          2          6          6         12          5          6
# 5          5          7          5         14          6          7
# 6          6          7          6         12          9          7

# %%
column_means = list(df3.mean())
column_means
# Out:
# [6.428571428571429,
#  7.428571428571429,
#  5.0,
#  12.142857142857142,
#  7.428571428571429,
#  6.428571428571429]

# %%
colnames = list(df3)
colnames
# Out:
# ['Student 1', 'Student 2', 'Student 3', 'Student 4', 'Student 5', 'Student 6']

# %%
list(zip(colnames, column_means))
# Out:
# [('Student 1', 6.428571428571429),
#  ('Student 2', 7.428571428571429),
#  ('Student 3', 5.0),
#  ('Student 4', 12.142857142857142),
#  ('Student 5', 7.428571428571429),
#  ('Student 6', 6.428571428571429)]

# %%
df_means = pd.DataFrame(zip(colnames, column_means))
df_means.columns = ['Students', 'Sleep Hours']
df_means
# Out:
#     Students  Sleep Hours
# 0  Student 1     6.428571
# 1  Student 2     7.428571
# 2  Student 3     5.000000
# 3  Student 4    12.142857
# 4  Student 5     7.428571
# 5  Student 6     6.428571

# %%
df_transposed = df3.transpose()
df_transposed
# Out:
#             0   1   2   3   4   5   6
# student
# Student 1  10   7   7   8   2   5   6
# Student 2   8   8   7   9   6   7   7
# Student 3   4   3   5   6   6   5   6
# Student 4  12  14  11  10  12  14  12
# Student 5  10   5   8   9   5   6   9
# Student 6   6   6   8   5   6   7   7

# %%
colnames = list(df_transposed)
colnames
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
newcols = ['Day ' + str(x+1) for x in colnames]
newcols
# Out:
# ['Day 1', 'Day 2', 'Day 3', 'Day 4', 'Day 5', 'Day 6', 'Day 7']

# %%
df_transposed.columns = newcols
df_transposed
# Out:
#            Day 1  Day 2  Day 3  Day 4  Day 5  Day 6  Day 7
# student
# Student 1     10      7      7      8      2      5      6
# Student 2      8      8      7      9      6      7      7
# Student 3      4      3      5      6      6      5      6
# Student 4     12     14     11     10     12     14     12
# Student 5     10      5      8      9      5      6      9
# Student 6      6      6      8      5      6      7      7

# %%
df_transposed.index.name = 'student'
df_transposed
# Out:
#            Day 1  Day 2  Day 3  Day 4  Day 5  Day 6  Day 7
# student
# Student 1     10      7      7      8      2      5      6
# Student 2      8      8      7      9      6      7      7
# Student 3      4      3      5      6      6      5      6
# Student 4     12     14     11     10     12     14     12
# Student 5     10      5      8      9      5      6      9
# Student 6      6      6      8      5      6      7      7

# %%
df_transposed.reset_index(inplace = True)
df_transposed
# Out:
#      student  Day 1  Day 2  Day 3  Day 4  Day 5  Day 6  Day 7
# 0  Student 1     10      7      7      8      2      5      6
# 1  Student 2      8      8      7      9      6      7      7
# 2  Student 3      4      3      5      6      6      5      6
# 3  Student 4     12     14     11     10     12     14     12
# 4  Student 5     10      5      8      9      5      6      9
# 5  Student 6      6      6      8      5      6      7      7

# %%
df_long = pd.melt(df_transposed, id_vars = 'student')
df_long
# Out:
#       student variable  value
# 0   Student 1    Day 1     10
# 1   Student 2    Day 1      8
# 2   Student 3    Day 1      4
# 3   Student 4    Day 1     12
# 4   Student 5    Day 1     10
# 5   Student 6    Day 1      6
# 6   Student 1    Day 2      7
# 7   Student 2    Day 2      8
# 8   Student 3    Day 2      3
# 9   Student 4    Day 2     14
# 10  Student 5    Day 2      5
# 11  Student 6    Day 2      6
# 12  Student 1    Day 3      7
# 13  Student 2    Day 3      7
# 14  Student 3    Day 3      5
# 15  Student 4    Day 3     11
# 16  Student 5    Day 3      8
# 17  Student 6    Day 3      8
# 18  Student 1    Day 4      8
# 19  Student 2    Day 4      9
# 20  Student 3    Day 4      6
# 21  Student 4    Day 4     10
# 22  Student 5    Day 4      9
# 23  Student 6    Day 4      5
# 24  Student 1    Day 5      2
# 25  Student 2    Day 5      6
# 26  Student 3    Day 5      6
# 27  Student 4    Day 5     12
# 28  Student 5    Day 5      5
# 29  Student 6    Day 5      6
# 30  Student 1    Day 6      5
# 31  Student 2    Day 6      7
# 32  Student 3    Day 6      5
# 33  Student 4    Day 6     14
# 34  Student 5    Day 6      6
# 35  Student 6    Day 6      7
# 36  Student 1    Day 7      6
# 37  Student 2    Day 7      7
# 38  Student 3    Day 7      6
# 39  Student 4    Day 7     12
# 40  Student 5    Day 7      9
# 41  Student 6    Day 7      7
